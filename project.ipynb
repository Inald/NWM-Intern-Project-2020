# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA

#tb.loc[tb['Instrument Classification (ISO 10962 CFI code)'].isin(['JFTXFP'])]
#tb.plot.hist(tb.groupby(['Trading platform']).Price.agg(['mean', max]))
#tb.describe()
#print(tb.shape)

df = pd.read_feather('rts27.feather')
#print(df.shape)
#df.head(20)
# Out:
# <bound method DataFrame.info of                 id bank_name                  legal_entity_name  \
# 0         77854033       UBS  UBS AG London Branch EMEA Trading
# 1         77854248       UBS  UBS AG London Branch EMEA Trading
# 2         77856619       UBS  UBS AG London Branch EMEA Trading
# 3         77818775       UBS  UBS AG London Branch EMEA Trading
# 4         77818788       UBS  UBS AG London Branch EMEA Trading
# ...            ...       ...                                ...
# 13064734  28634664  Barclays                  Barclays Bank PLC
# 13064735  28634665  Barclays                  Barclays Bank PLC
# 13064736  28634666  Barclays                  Barclays Bank PLC
# 13064737  28634667  Barclays                  Barclays Bank PLC
# 13064738  28634673  Barclays                  Barclays Bank PLC
#
#                                                   file_name  \
# 0                                   UBSB_UBSY_QOE_Q4_T6.csv
# 1                                   UBSB_UBSY_QOE_Q4_T6.csv
# 2                                   UBSB_UBSY_QOE_Q4_T6.csv
# 3                                   UBSB_UBSY_QOE_Q4_T6.csv
# 4                                   UBSB_UBSY_QOE_Q4_T6.csv
# ...                                                     ...
# 13064734  RTS27_Article_6_Likelihood_of_Execution_Report...
# 13064735  RTS27_Article_6_Likelihood_of_Execution_Report...
# 13064736  RTS27_Article_6_Likelihood_of_Execution_Report...
# 13064737  RTS27_Article_6_Likelihood_of_Execution_Report...
# 13064738  RTS27_Article_6_Likelihood_of_Execution_Report...
#
#          date_of_trading_day instrument_identifier instrument_classification  \
# 0                 2018-12-18          CH0386503236                      None
# 1                 2018-12-20          CH0386504416                      None
# 2                 2018-10-08          CH0394745357                      None
# 3                 2018-11-27          AN8068571086                      None
# 4                 2018-10-31          AN8068571086                      None
# ...                      ...                   ...                       ...
# 13064734          2018-07-13          US48125LRN46                      None
# 13064735          2018-07-05          US48125LRN46                      None
# 13064736          2018-07-18          US48125LRN46                      None
# 13064737          2018-08-02          EZ8FY0MMPMW4                      None
# 13064738          2018-08-27          EZKW618C2X38                      None
#
#           order_request_quotes_received  executed_transactions  \
# 0                                   0.0                    1.0
# 1                                   0.0                    2.0
# 2                                   0.0                    1.0
# 3                                   0.0                    2.0
# 4                                   0.0                    4.0
# ...                                 ...                    ...
# 13064734                            4.0                    0.0
# 13064735                            4.0                    0.0
# 13064736                            2.0                    0.0
# 13064737                            1.0                    0.0
# 13064738                            2.0                    0.0
#
#           total_value_of_transactions  ...  median_transaction_size_eur  \
# 0                                20.0  ...                    20.000000
# 1                               400.0  ...                   200.000000
# 2                               100.0  ...                   100.000000
# 3                              3184.0  ...                  2723.487198
# 4                             77641.0  ...                   963.780919
# ...                               ...  ...                          ...
# 13064734                          NaN  ...                          NaN
# 13064735                          NaN  ...                          NaN
# 13064736                          NaN  ...                          NaN
# 13064737                          NaN  ...                          NaN
# 13064738                          NaN  ...                          NaN
#
#           median_transaction_size_gbp  median_size_request_quotes_eur  \
# 0                           17.981601                             NaN
# 1                          180.523989                             NaN
# 2                           87.869988                             NaN
# 3                         2413.062250                             NaN
# 4                          854.948672                             NaN
# ...                               ...                             ...
# 13064734                          NaN                             NaN
# 13064735                          NaN                             NaN
# 13064736                          NaN                             NaN
# 13064737                          NaN                             NaN
# 13064738                          NaN                             NaN
#
#           median_size_request_quotes_gbp  smartie_instrument_name  \
# 0                                    NaN                     None
# 1                                    NaN                     None
# 2                                    NaN                     None
# 3                                    NaN                     None
# 4                                    NaN                     None
# ...                                  ...                      ...
# 13064734                             NaN                     None
# 13064735                             NaN                     None
# 13064736                             NaN                     None
# 13064737                             NaN                     None
# 13064738                             NaN                     None
#
#          data_quality_flag egb_eligible_flag year_quarter business  \
# 0                        Y              None      2018 Q4     None
# 1                        Y              None      2018 Q4     None
# 2                        Y              None      2018 Q4     None
# 3                        Y              None      2018 Q4     None
# 4                        Y              None      2018 Q4     None
# ...                    ...               ...          ...      ...
# 13064734              None              None      2018 Q3     None
# 13064735              None              None      2018 Q3     None
# 13064736              None              None      2018 Q3     None
# 13064737              None              None      2018 Q3     None
# 13064738              None              None      2018 Q3     None
#
#          central_bank_isin_flag
# 0                          None
# 1                          None
# 2                          None
# 3                          None
# 4                          None
# ...                         ...
# 13064734                      Y
# 13064735                      Y
# 13064736                      Y
# 13064737                   None
# 13064738                   None
#
# [13064739 rows x 37 columns]>

# %%
from sklearn.preprocessing import StandardScaler
from sklearn import preprocessing
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# Select target
y = df['date_created']
# To keep things simple, we'll use only numerical predictors
predictors = df.drop(['date_created'], axis=1)
X = df

# Divide data into training and validation subsets
X_train, X_valid, y_train, y_valid = train_test_split(X, y, train_size=0.8, test_size=0.2,
                                                      random_state=0)

# %%
from sklearn.impute import SimpleImputer

# Imputation
my_imputer = SimpleImputer(missing_values='NaN', strategy = 'most_frequent')
imputed_X_train = pd.DataFrame(my_imputer.fit_transform(X_train))
imputed_X_valid = pd.DataFrame(my_imputer.transform(X_valid))

# Imputation removed column names; put them back
imputed_X_train.columns = X_train.columns
imputed_X_valid.columns = X_valid.columns

print(imputed_X_train.columns.isnull().sum())

# %%
from sklearn.preprocessing import LabelEncoder

# Get list of categorical variables
s = (X_train.dtypes == 'object')
object_cols = list(s[s].index)

print("Categorical variables:")
print(object_cols)

# Make copy to avoid changing original data 
label_X_train = X_train.copy()
label_X_valid = X_valid.copy()

# Apply label encoder to each column with categorical data
label_encoder = LabelEncoder()
for col in object_cols:
    label_encoder.fit(pd.concat([X_train[col], X_valid[col]], axis=0, sort=False))
    label_X_train[col] = label_encoder.transform(X_train[col])
    label_X_valid[col] = label_encoder.transform(X_valid[col])
# Out:
# Categorical variables:
# ['bank_name', 'legal_entity_name', 'file_name', 'instrument_identifier', 'instrument_classification', 'active', 'source_instrument_desc', 'source_instrument_ccy', 'source_market_segment', 'smartie_instrument_id', 'systematic_internaliser_flag', 'liquidity_provider_flag', 'traded_in_natwest_markets', 'source_instrument_name', 'smartie_instrument_name', 'data_quality_flag', 'egb_eligible_flag', 'year_quarter', 'business', 'central_bank_isin_flag']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\sklearn\preprocessing\_label.py in _encode(values, uniques, encode, check_unknown)
#     112         try:
# --> 113             res = _encode_python(values, uniques, encode)
#     114         except TypeError:
#
# ~\anaconda3\lib\site-packages\sklearn\preprocessing\_label.py in _encode_python(values, uniques, encode)
#      60     if uniques is None:
# ---> 61         uniques = sorted(set(values))
#      62         uniques = np.array(uniques, dtype=values.dtype)
#
# TypeError: '<' not supported between instances of 'NoneType' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-54-bd45293933c1> in <module>
#      15 label_encoder = LabelEncoder()
#      16 for col in object_cols:
# ---> 17     label_encoder.fit(pd.concat([X_train[col], X_valid[col]], axis=0, sort=False))
#      18     label_X_train[col] = label_encoder.transform(X_train[col])
#      19     label_X_valid[col] = label_encoder.transform(X_valid[col])
#
# ~\anaconda3\lib\site-packages\sklearn\preprocessing\_label.py in fit(self, y)
#     238         """
#     239         y = column_or_1d(y, warn=True)
# --> 240         self.classes_ = _encode(y)
#     241         return self
#     242
#
# ~\anaconda3\lib\site-packages\sklearn\preprocessing\_label.py in _encode(values, uniques, encode, check_unknown)
#     115             types = sorted(t.__qualname__
#     116                            for t in set(type(v) for v in values))
# --> 117             raise TypeError("Encoders require their input to be uniformly "
#     118                             f"strings or numbers. Got {types}")
#     119         return res
#
# TypeError: Encoders require their input to be uniformly strings or numbers. Got ['NoneType', 'str']

# %%
    
df.loc[df['instrument_classification'].isin(['JFTXFP'])]
df.dropna(axis=1, thresh=1000000)
df.drop(columns=['designated_market_makers','legal_entity_name', 'systematic_internaliser_flag'])
pd.get_dummies(df)
